# %%
import numpy, math

lst = []
posicao = []
somalinha = []
auxa = int(1)
auxb = []
auxc = int()
D = int(1)
num = int(input())

for i in range (0, num):
  for j in range (0, num):
    a = float(input())
    lst.append(a)
  auxb.append(lst)
  somalinha.append(0.)
  posicao.append(-1.0)
  lst = []
for i in range (0, num):
  for j in range (0, num):
    somalinha[i] += abs(auxb[i][j])

for i in range (0, num):
  for j in range (0, num):
    if abs(2*auxb[i][j]) > somalinha[i]:
      posicao[i] = j

for i in range (0, num):
  if posicao[i] != i:
    D = 2

for i in range (0, num):
  if posicao[i] == -1:
    D = 0
    break

for i in range (0, num):
  for j in range (0, num):
    if i != j and posicao[i] == posicao[j]:
      D = 0
      break

    
    

if D == 2:
  print("a matriz possui dominancia se trocar linhas:")
  for i in range(0, num):
    print("L" + str(i) + " vai para L" + str(posicao[i]))

if D == 1:
  print("a matriz possui dominancia.")

if D == 0:
  print("a matriz nao possui dominancia, mesmo se trocar linhas.")
# Out:
# 3
# 5
# 2
# 1
# 4
# 5
# 0
# 1
# 2
# 7
# a matriz possui dominancia.
