# %%
import math, numpy
num = int(input())
auxa = []
auxb = []
auxc = []
auxd = []
auxf = []
auxg = []

for i in range(0, num):
  for j in range(0, num):
    auxa =  float(input())
    auxb.append(auxa)
    somalinha += auxb
  auxc.append(auxb)
  a = somalinha
# Out:
# 2
# 1
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-ff1c7caea6dd> in <module>
#      12     auxa =  float(input())
#      13     auxb.append(auxa)
# ---> 14     somalinha += auxb
#      15   auxc.append(auxb)
#      16   a = somalinha
#
# TypeError: unsupported operand type(s) for +=: 'float' and 'list'
