# %%
N = int(input())
a = int()
lst = []
lst_ = []
M = []
b = []
p = []
x = []
z = []
c = []
sominha123 = float(0.)
soma1 = float(0.)
cristianoronaldo321 = float(0.)
cristianoronaldo321compivot = float(0.)
errosempivot = float()
errocompivot = float()

for i in range(0, N):
  for j in range(0, N):
    lst.append(0.)
    lst_.append(0.)
  M.append(lst)
  lst = []
  lst_ = []
  if i == 0:
    b.append(7.)
  elif i < N-1:
    b.append(15.)
  else:
    b.append(14.)
  x.append(0.)
  z.append(0.)

 

for i in range(0, N):
  for j in range(0, N):
    if i == j:
      M[i][j] = 6
    elif i == j-1:
      M[i][j] = 1
    elif i == j+1:
      M[i][j] = 8
    else:
      M[i][j] = 0

for j in range(0, N):
  for i in range(0, N):
    if j < i:
      if M[i][j] != 0:
        r = M[i][j] / M[j][j]
        for k in range(0, N):
          M[i][k] = M[i][k] - r*M[j][k]
        b[i] = b[i] - r * b[j]


for j in range(0, N):
  for i in range(0, N):
    if j < i:
      if M[i][j] != 0:
        r = M[i][j] / M[j][j]
        for k in range(0, N):
          M[i][k] = M[i][k] - r*M[j][k]
        c[i] = c[i] - r * c[j]



def erro(a, b):
  errinho = a-b
  if errinho < 0:
    errinho = errinho*(-1)
  return errinho


j = N-1
while j >= 0:
  x[j] = b[j]/M[j][j]
  z = x
  i = N-1
  while i > j:
    x[j] += (-M[j][i])*(x[i])/(M[j][j])
    i -= 1
  j -= 1
def modulo(haalandinho):
  if haalandinho < 0:
    haalandinho = -haalandinho
  return haalandinho


for i in range(0, N):
  cristianoronaldo321 = (modulo(x[i]))
  errosempivot = (modulo(N - cristianoronaldo321))
errocompivot += errosempivot

 




print("erro_sem_pivo = ", round(errosempivot,6), "\nerro_com_pivo = ", round(errocompivot,6))
# Out:
# 3
# erro_sem_pivo =  2.0
# erro_com_pivo =  2.0
