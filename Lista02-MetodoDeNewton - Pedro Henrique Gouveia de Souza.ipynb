# %%
import math
A = float(input())
B = float(input())
C = float(input())
D = float(input())
X0 = float(input())
xatual = float(0)
Xi = float(0)
numint = int(0)
funcao = float(0)
derivada = float(0)

xatual = X0

funcao = ((A*(X0**3)) + (B*(X0**2)) + (C*X0) + D)
derivada = ((3*A*(X0**2)) + (2*B*X0) + C)
Xi = (X0 - (funcao/derivada))
numint += 1

while (((Xi-X0) > 10**(-4))or(-1*(Xi-X0) > 10**(-4))):
  X0 = Xi
  funcao = ((A*(X0**3)) + (B*(X0**2)) + (C*X0) + D)
  derivada = ((3*A*(X0**2)) + (2*B*X0) + C)
  Xi = (X0 - (funcao/derivada))
  numint += 1

  
  

print(round(Xi,3), numint)
# Out:
# 1
# 2
# -11
# 1
# 1.0
# 0.093 5
